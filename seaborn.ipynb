# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('mtcars.csv')

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
res=sns.barplot(x='cyl',y='mpg',data=df,color='green')
plt.show()

# %%
res=sns.barplot(x='am',y='mpg',data=df,palette='gist_rainbow_r')

# %%
sns.countplot(x='cyl',data=df,palette='Set1')
# Out:
# <Axes: xlabel='cyl', ylabel='count'>

# %%
df['cyl'].value_counts()
# Out:
# cyl
# 8    14
# 4    11
# 6     7
# Name: count, dtype: int64

# %%
sns.countplot(x='hp',data=df)
# Out:
# <Axes: xlabel='hp', ylabel='count'>

# %%
sns.barplot(x='hp',y='model',data=df,dodge=True)
# Out:
# <Axes: xlabel='hp', ylabel='model'>

# %%
sns.countplot(x='carb',data=df)
# Out:
# <Axes: xlabel='carb', ylabel='count'>

# %%
sns.countplot(x='gear',hue='cyl',data=df)
# Out:
# <Axes: xlabel='gear', ylabel='count'>

# %%
sns.countplot(x='gear',hue='carb',data=df)
# Out:
# <Axes: xlabel='gear', ylabel='count'>

# %%
sns.distplot(df.mpg,bins=10,color='g')
# Out:
# <Axes: xlabel='mpg', ylabel='Density'>

# %%
sns.distplot(df.disp,bins=10,color='r')
# Out:
# <Axes: xlabel='disp', ylabel='Density'>

# %%
sns.distplot(df.qsec,bins=10,color='b')
# Out:
# <Axes: xlabel='qsec', ylabel='Density'>

# %%
ndf=df.select_dtypes(include='number')
sns.heatmap(ndf.corr())
# Out:
# <Axes: >

# %%
df1=sns.load_dataset('tips')

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
cdf=df1.select_dtypes(include='number')
cdf.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(cdf.corr())
# Out:
# <Axes: >

# %%
sns.jointplot(x='tip',y='total_bill',data=df1,kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill',data=df1,kind='reg')

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df1,hue='sex')

# %%
sns.distplot(df1['tip'],bins=10)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.distplot(df1['tip'],kde=False,bins=10)
# Out:
# <Axes: xlabel='tip'>

# %%
sns.boxplot(x='day',y='total_bill',data=df1,palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',hue='smoker',data=df1,palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=df1,orient='v')
# Out:
# <Axes: >

# %%
sns.violinplot(x="total_bill",y="day",data=df1,palette='rainbow')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>
